# %%
from calculations import calculate_shear, calculate_delta_t, calculate_delta_t_per_height, classify_stability

# Row 1 test
shear = calculate_shear(9, 3.45, 59, 22)
delta_t = calculate_delta_t(9.7, 7.9)
delta_t_h = calculate_delta_t_per_height(delta_t)
stability = classify_stability(delta_t_h)

print("Shear:", shear)
print("Delta T:", delta_t)
print("Delta T/H:", delta_t_h)
print("Stability:", stability)
# Out:
# Shear: 0.972
# Delta T: 4.8649
# Delta T/H: 13.1484
# Stability: Unstable
